# %% [markdown]
# # JVM Performance Bottleneck Diagnostician
#
# This notebook demonstrates the jvm_perf_agent package.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('src').resolve()))
from jvm_perf_agent.agent import analyze_performance_run
print('Package loaded')

# %%
jmeter_csv = 'elapsed,success\n1200,True\n1300,True'
jvm_json = '{"threads": 10, "gc_count": 1, "cpu": 95}'
result = analyze_performance_run(jmeter_csv=jmeter_csv, jvm_json=jvm_json, source_format='strings')
print('Diagnosis:', result.get('diagnosis') if isinstance(result, dict) else result)
